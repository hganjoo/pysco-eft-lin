# %%
pwd

# %%
import numpy as np
import matplotlib.pyplot as plt
import pspec

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Computer Modern']

# %%
# Start z = 25

plt.figure(dpi=150)

for i in [0,1,10,15,18,20,30,35,40]:


    file_path = './ptest-c/output_{}/particles_eft_multigrid_ncoarse7.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    #plt.loglog(k,Pk,c='k')
    
    file_path = './ptest-c/output_{}/particles_parametrized_mu0_0.25_multigrid_ncoarse7.h5'.format(str(i).zfill(5))
    k,Pkp,a = pspec.get_pspec(file_path)
    #plt.loglog(k,Pk,c='r',lw=0.5)
    #print(a)
    
    
    file_path = '../../pysco-eft-testlin/pysco/pt-5d-ini/output_{}/particles_eft_multigrid_ncoarse7.h5'.format(str(i).zfill(5))
    k,Pkql,a = pspec.get_pspec(file_path)
    #plt.plot(k,Pkql,markerfacecolor='none',alpha=1,lw=0.5,ls='dashed')
    #print(a)
    
    '''plt.title(r'$z = $' + ' {:.6f}'.format(1/a-1));
    plt.xlabel('$k$')
    plt.ylabel('$P(k)$')'''
    
    plt.semilogx(k,Pkql/Pkp,label='{:.2f}'.format(a),lw=1,alpha=0.5)



plt.legend(fontsize=8,ncol=2)
#plt.title('Start z = 50')

# %%
# Start z = 50

plt.figure(dpi=150)

for i in [0,1,10,15,18,20,30,35,40]:


    file_path = './ptest-c/output_{}/particles_eft_multigrid_ncoarse7.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    #plt.loglog(k,Pk,c='k')
    
    file_path = './ptest-c/output_{}/particles_parametrized_mu0_0.25_multigrid_ncoarse7.h5'.format(str(i).zfill(5))
    k,Pkp,a = pspec.get_pspec(file_path)
    #plt.loglog(k,Pk,c='r',lw=0.5)
    #print(a)
    
    
    file_path = '../../pysco-eft-testlin/pysco/pt-5d-ini/output_{}/particles_eft_multigrid_ncoarse7.h5'.format(str(i).zfill(5))
    k,Pkql,a = pspec.get_pspec(file_path)
    #plt.plot(k,Pkql,markerfacecolor='none',alpha=1,lw=0.5,ls='dashed')
    #print(a)
    
    '''plt.title(r'$z = $' + ' {:.6f}'.format(1/a-1));
    plt.xlabel('$k$')
    plt.ylabel('$P(k)$')'''
    
    plt.semilogx(k,Pkql/Pkp,label='{:.2f}'.format(a),lw=1,alpha=0.5)



plt.legend(fontsize=8,ncol=2)

# %%
plt.figure(dpi=150)

for i in [40]:


    file_path = './ptest-c/output_{}/particles_eft_multigrid_ncoarse7.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    #plt.loglog(k,Pk,c='k',lw=2,ls='dotted')
    
    file_path = './ptest-c/output_{}/particles_parametrized_mu0_0.25_multigrid_ncoarse7.h5'.format(str(i).zfill(5))
    k,Pkp,a = pspec.get_pspec(file_path)
    plt.loglog(k,Pk,c='r',lw=1,alpha=0.7)
    print(a)
    
    
    file_path = '../../pysco-eft-testlin/pysco/pt-5d-ini/output_{}/particles_eft_multigrid_ncoarse7.h5'.format(str(i).zfill(5))
    file_path = '/Users/himanishganjoo/Dropbox/prograceray/pysco-eft-testlin-modpoisson/pysco/pt-modp1/output_{}/particles_eft_multigrid_ncoarse7.h5'.format(str(i).zfill(5))
    k,Pkql,a = pspec.get_pspec(file_path)
    plt.plot(k,Pkql,markerfacecolor='none',alpha=1,lw=1,ls='dashed')
    print(a)

    
    file_path = '/Users/himanishganjoo/Dropbox/prograceray/pysco-eft-testlin-modpoisson/pysco/pt-modp1//power/pk_eft_multigrid_ncoarse7_00089.dat'
    x = np.loadtxt(file_path)
    #plt.loglog(x[:,0],x[:,1],'x')

    
    
    '''plt.title(r'$z = $' + ' {:.6f}'.format(1/a-1));
    plt.xlabel('$k$')
    plt.ylabel('$P(k)$')'''
    
    #plt.semilogx(k,Pkql/Pk,label='{:.2f}'.format(a),lw=1,alpha=0.5)



plt.legend()
# Out:
# 1.0
# 1.0
# /var/folders/52/c4dmyzws4ps4lw3vl0112df00000gp/T/ipykernel_42583/605008893.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#plt.semilogx(k,Pkq/Pk,'.',label='2-pt gradient; Npre,Npost=3')
plt.semilogx(k,Pkql/Pk,'.')
plt.legend()
plt.title('Mean: {:.4f}'.format(np.mean(Pkql/Pk)))
# Out:
# /var/folders/52/c4dmyzws4ps4lw3vl0112df00000gp/T/ipykernel_42583/3967373297.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0.5, 1.0, 'Mean: 1.1338')

# %%
np.mean(Pkql/Pk)

# %%
# LCDM



for i in range(41):
    plt.figure(dpi=200,figsize=(5,3))
    file_path = './tester/power/pk_eft_multigrid_ncoarse5_{}.dat'.format(str(i).zfill(5))
    
    with open(file_path, 'r') as file:
            a = float(file.readline().strip().split(' ')[-1])
    
    x = np.loadtxt(file_path.replace('eft','newton'))
    plt.loglog(x[:,0],x[:,1],'.')
    
    x = np.loadtxt(file_path)
    plt.loglog(x[:,0],x[:,1],'x')
    
    plt.legend(labels=['EFT','LCDM'][::-1])
    
    
    plt.title('$z$ = {:.2f}'.format(1/a - 1))
    plt.ylim(0.1,1e5)
    plt.xlabel('$k$')
    plt.ylabel('$P(k)$')
    plt.savefig('powerpics/{}.png'.format(str(i).zfill(5)),dpi=400,bbox_inches='tight')
    plt.close()

# %%
first_line

# %%
from PIL import Image

# Create a list to hold the images
images = []

# Loop to read 41 images
for i in range(41):
    # Generate the filename with leading zeros (e.g., 00001.png)
    filename = f"powerpics/{i:05}.png"
    # Open the image and append to the list
    img = Image.open(filename)
    images.append(img)

# Save as a GIF
output_gif = "powerpics/output.gif"
images[0].save(output_gif, save_all=True, append_images=images[1:], optimize=False, duration=300, loop=0)

print(f"GIF saved as {output_gif}")

# %%
for i in range(41):
    plt.figure(dpi=200,figsize=(5,3))
    
    file_path = './t4/output_{}/particles_eft_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    plt.loglog(k,Pk,'.')

    file_path = './t1/output_{}/particles_eft_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    plt.loglog(k,Pk,'.')

    file_path = './t4/output_{}/particles_newton_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    plt.loglog(k,Pk)
    
    
    
    plt.legend(labels=[r'EFT: $\alpha_{M0} = 0.4$',r'EFT: $\alpha_{M0} = 0.3$','LCDM'])
    plt.title('$z$ = {:.2f}'.format(1/a - 1))
    plt.ylim(0.001,1e5)
    plt.xlabel('$k$')
    plt.ylabel('$P(k)$')

    plt.savefig('powerpics_am05/{}.png'.format(str(i).zfill(5)),dpi=400,bbox_inches='tight')
    plt.close()

# %%
from PIL import Image

# Create a list to hold the images
images = []

# Loop to read 41 images
for i in range(41):
    # Generate the filename with leading zeros (e.g., 00001.png)
    filename = f"powerpics_am05/{i:05}.png"
    # Open the image and append to the list
    img = Image.open(filename)
    images.append(img)

# Save as a GIF
output_gif = "powerpics_am05/output.gif"
images[0].save(output_gif, save_all=True, append_images=images[1:], optimize=False, duration=300, loop=0)

print(f"GIF saved as {output_gif}")

# %%
for i in range(7):
    plt.figure(dpi=200,figsize=(5,3))
    
    file_path = './t4/output_{}/particles_eft_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    plt.loglog(k,Pk,'.')

    file_path = './tb03m04/output_{}/particles_eft_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    plt.loglog(k,Pk,'.')

    file_path = './t4/output_{}/particles_newton_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    plt.loglog(k,Pk)
    
    
    
    plt.legend(labels=[r'EFT: $\alpha_{M0} = 0.4$, $\alpha_{B0} = 0.1$',r'EFT: $\alpha_{M0} = 0.4$, $\alpha_{B0} = 0.3$','LCDM'])
    plt.title('$z$ = {:.2f}'.format(1/a - 1))
    plt.ylim(0.001,1e5)
    plt.xlabel('$k$')
    plt.ylabel('$P(k)$')

    plt.savefig('powerpics_amc/{}.png'.format(str(i).zfill(5)),dpi=400,bbox_inches='tight')
    plt.close()

# %%
for i in range(41):
    plt.figure(dpi=200,figsize=(5,3))
    
    file_path = './ptestn/output_{}/particles_eft_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    plt.loglog(k,Pk,'.')

    file_path = './ptestn//output_{}/particles_parametrized_mu0_-0.072_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
    k,Pk,a = pspec.get_pspec(file_path)
    plt.loglog(k,Pk,'.')

    
    
    
    plt.legend(labels=['EFT','Param'])
    plt.title('$z$ = {:.2f}'.format(1/a - 1))
    plt.ylim(0.001,1e5)
    plt.xlabel('$k$')
    plt.ylabel('$P(k)$')

    plt.savefig('powerpics_ptestn/{}.png'.format(str(i).zfill(5)),dpi=400,bbox_inches='tight')
    plt.close()

# %%
from PIL import Image

# Create a list to hold the images
images = []

# Loop to read 41 images
for i in range(41):
    # Generate the filename with leading zeros (e.g., 00001.png)
    filename = f"powerpics_ptestn/{i:05}.png"
    # Open the image and append to the list
    img = Image.open(filename)
    images.append(img)

# Save as a GIF
output_gif = "powerpics_ptestn/output.gif"
images[0].save(output_gif, save_all=True, append_images=images[1:], optimize=False, duration=300, loop=0)

print(f"GIF saved as {output_gif}")

# %%
plt.figure(dpi=200,figsize=(4,3))

file_path = './ptest/output_{}/particles_eft_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
k,Pk1,a = pspec.get_pspec(file_path)
#plt.loglog(k,Pk,'.',c='r')

file_path = './ptest//output_{}/particles_parametrized_mu0_-0.072_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
k,Pk2,a = pspec.get_pspec(file_path)
plt.semilogx(k,Pk1/Pk2,c='r',label=r'$w_a = 0$')

file_path = './ptestn/output_{}/particles_eft_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
k,Pk1,a = pspec.get_pspec(file_path)
#plt.loglog(k,Pk,'.',c='r')

file_path = './ptestn//output_{}/particles_parametrized_mu0_-0.072_multigrid_ncoarse8.h5'.format(str(i).zfill(5))
k,Pk2,a = pspec.get_pspec(file_path)
plt.semilogx(k,Pk1/Pk2,c='g',label=r'$w_a = -0.2$')

plt.title('EFT-Parametrized Ratio of Power Spectra, $z=0$')
plt.xlabel('$k$')
plt.legend()
